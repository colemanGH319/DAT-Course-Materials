# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing Chipotle Data
#
# _Author: Joseph Nelson (DC)_
#
# ---

# %% [markdown]
# For Project 2, you will complete a series of exercises exploring [order data from Chipotle](https://github.com/TheUpshot/chipotle), compliments of _The New York Times'_ "The Upshot."
#
# For these exercises, you will conduct basic exploratory data analysis (Pandas not required) to understand the essentials of Chipotle's order data: how many orders are being made, the average price per order, how many different ingredients are used, etc. These allow you to practice business analysis skills while also becoming comfortable with Python.

# %% [markdown]
# ---
#
# ## Basic Level

# %% [markdown]
# ### Part 1: Read in the file with `csv.reader()` and store it in an object called `file_nested_list`.
#
# Hint: This is a TSV (tab-separated value) file, and `csv.reader()` needs to be told [how to handle it](https://docs.python.org/2/library/csv.html).

# %%
import csv
from collections import namedtuple   # Convenient to store the data rows
import pandas as pd

DATA_FILE = './data/chipotle.tsv'

# %%
# For loop is used to append new rows to the dataframe
hasheader = False
created_df = False
with open('./data/chipotle.tsv') as tsvfile:
    # Load tsv file in
    using_csv_reader_is_pointless_pandas_is_better = csv.reader(tsvfile, delimiter='\t')
    for row in using_csv_reader_is_pointless_pandas_is_better:
        # For loop that loads the rows in one at a time. Creates a new df and appends it to existing one
        if hasheader == False:
            the_header = row
            hasheader = True
        elif created_df == False:
            file_nested_list = pd.DataFrame([row], columns = the_header)
            created_df = True
        else:
            new_df = pd.DataFrame([row], columns = the_header) 
            file_nested_list = file_nested_list.append(new_df)
file_nested_list.head()
# Out:
#   order_id quantity                              item_name  \
# 0        1        1           Chips and Fresh Tomato Salsa
# 0        1        1                                   Izze
# 0        1        1                       Nantucket Nectar
# 0        1        1  Chips and Tomatillo-Green Chili Salsa
# 0        2        2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                               NULL     $2.39
# 0                                       [Clementine]     $3.39
# 0                                            [Apple]     $3.39
# 0                                               NULL     $2.39
# 0  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# More efficient way to load data
import pandas as pd
chipotle = pd.read_csv(DATA_FILE, sep='\t')

# %% [markdown]
# ### Part 2: Separate `file_nested_list` into the `header` and the `data`.

# %%
header = file_nested_list.columns
print(header)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
just_the_data = file_nested_list.to_string(header=False)
print(just_the_data)
# Out:
# 0     1   1           Chips and Fresh Tomato Salsa                                               NULL   $2.39
# 0     1   1                                   Izze                                       [Clementine]   $3.39
# 0     1   1                       Nantucket Nectar                                            [Apple]   $3.39
# 0     1   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0     2   2                           Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  $16.98
# 0     3   1                           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...  $10.98
# 0     3   1                          Side of Chips                                               NULL   $1.69
# 0     4   1                          Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.75
# 0     4   1                       Steak Soft Tacos  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...   $9.25
# 0     5   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...   $9.25
# 0     5   1                    Chips and Guacamole                                               NULL   $4.45
# 0     6   1                   Chicken Crispy Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $8.75
# 0     6   1                     Chicken Soft Tacos  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $8.75
# 0     7   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0     7   1                    Chips and Guacamole                                               NULL   $4.45
# 0     8   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0     8   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0     9   1                        Chicken Burrito  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...   $8.49
# 0     9   2                            Canned Soda                                           [Sprite]   $2.18
# 0    10   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...   $8.75
# 0    10   1                    Chips and Guacamole                                               NULL   $4.45
# 0    11   1                       Barbacoa Burrito  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...   $8.99
# 0    11   1                       Nantucket Nectar                               [Pomegranate Cherry]   $3.39
# 0    12   1                        Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...  $10.98
# 0    12   1                                   Izze                                       [Grapefruit]   $3.39
# 0    13   1           Chips and Fresh Tomato Salsa                                               NULL   $2.39
# 0    13   1                           Chicken Bowl  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...   $8.49
# 0    14   1                       Carnitas Burrito  [[Tomatillo-Green Chili Salsa (Medium), Roaste...   $8.99
# 0    14   1                            Canned Soda                                       [Dr. Pepper]   $1.09
# 0    15   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0    15   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0    16   1                          Steak Burrito  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...   $8.99
# 0    16   1                          Side of Chips                                               NULL   $1.69
# 0    17   1                          Carnitas Bowl  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.99
# 0    17   1                          Bottled Water                                               NULL   $1.09
# 0    18   1                     Chicken Soft Tacos                   [Roasted Chili Corn Salsa, Rice]   $8.75
# 0    18   1                     Chicken Soft Tacos      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]   $8.75
# 0    18   1                    Chips and Guacamole                                               NULL   $4.45
# 0    18   1  Chips and Tomatillo Green Chili Salsa                                               NULL   $2.95
# 0    19   1                          Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.75
# 0    19   1                                  Chips                                               NULL   $2.15
# 0    20   1                    Chips and Guacamole                                               NULL   $4.45
# 0    20   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...  $11.25
# 0    20   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...  $11.75
# 0    20   1                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...   $8.75
# 0    21   1                        Chicken Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  $10.98
# 0    21   1                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...   $8.99
# 0    21   1                                   Izze                                       [Blackberry]   $3.39
# 0    22   1                          Steak Burrito  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...   $8.99
# 0    22   1                    Chips and Guacamole                                               NULL   $3.99
# 0    23   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...   $8.99
# 0    23   2                            Canned Soda                                     [Mountain Dew]   $2.18
# 0    24   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Black Bea...  $10.98
# 0    24   1                            Canned Soda                                           [Sprite]   $1.09
# 0    25   1                             Steak Bowl  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...   $8.99
# 0    25   1           Chips and Fresh Tomato Salsa                                               NULL   $2.39
# 0    26   1                    Barbacoa Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Black...   $9.25
# 0    26   1                         Veggie Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.25
# 0    27   1                          Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.75
# 0    27   1                                  Chips                                               NULL   $2.15
# 0    28   1                    Chips and Guacamole                                               NULL   $4.45
# 0    28   1                       Steak Soft Tacos                       [Fresh Tomato Salsa, Cheese]   $9.25
# 0    28   1                            Veggie Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0    28   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]   $8.75
# 0    29   1                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.99
# 0    29   1                       Steak Soft Tacos  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...   $8.99
# 0    30   1                                   Izze                                       [Blackberry]   $3.39
# 0    30   1                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Rice, Cheese]]   $8.99
# 0    30   1                        Chicken Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...  $10.98
# 0    31   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0    31   1                          Side of Chips                                               NULL   $1.69
# 0    32   1                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.99
# 0    32   1                    Chips and Guacamole                                               NULL   $3.99
# 0    33   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0    33   1                    Chips and Guacamole                                               NULL   $4.45
# 0    34   1                     Chicken Soft Tacos  [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...   $8.75
# 0    34   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...   $8.75
# 0    34   1                                  Chips                                               NULL   $2.15
# 0    34   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0    35   1                     Chicken Soft Tacos  [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...  $11.25
# 0    35   1                                  Chips                                               NULL   $2.15
# 0    36   1                       Barbacoa Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...   $9.25
# 0    36   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0    37   1                        Chicken Burrito  [Tomatillo Green Chili Salsa, [Rice, Black Bea...   $8.75
# 0    37   1                       Steak Soft Tacos                        [Tomatillo Red Chili Salsa]   $9.25
# 0    38   1                            Veggie Bowl  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...   $8.49
# 0    38   1                             Steak Bowl  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...   $8.99
# 0    38   1                          Bottled Water                                               NULL   $1.09
# 0    39   1                       Carnitas Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour ...   $9.25
# 0    39   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0    40   1                             Steak Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.75
# 0    40   1                             Steak Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...  $11.75
# 0    40   1                     Steak Crispy Tacos                   [Fresh Tomato Salsa, Sour Cream]   $9.25
# 0    41   1                       Carnitas Burrito  [Roasted Chili Corn Salsa, [Sour Cream, Guacam...  $11.75
# 0    41   1                    Chips and Guacamole                                               NULL   $4.45
# 0    42   1                          Barbacoa Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $9.25
# 0    42   1                    Chips and Guacamole                                               NULL   $4.45
# 0    43   1                          Carnitas Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.75
# 0    43   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0    44   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...   $8.75
# 0    44   1                    Chips and Guacamole                                               NULL   $4.45
# 0    45   1                          Steak Burrito  [Tomatillo-Green Chili Salsa (Medium), [Rice, ...   $8.99
# 0    45   1                             Steak Bowl  [Tomatillo-Green Chili Salsa (Medium), [Rice, ...   $8.99
# 0    45   1                    Chips and Guacamole                                               NULL   $3.99
# 0    46   1                         Veggie Burrito  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...   $8.49
# 0    46   1                       Nantucket Nectar                          [Pineapple Orange Banana]   $3.39
# 0    47   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0    47   1                            Canned Soda                                       [Dr. Pepper]   $1.09
# 0    48   1                          Steak Burrito  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $9.25
# 0    48   1                    Chips and Guacamole                                               NULL   $4.45
# 0    49   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0    49   1    Chips and Tomatillo Red Chili Salsa                                               NULL   $2.95
# 0    49   1                    Chips and Guacamole                                               NULL   $4.45
# 0    50   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0    50   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0    51   1                          Barbacoa Bowl  [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...   $8.99
# 0    51   1                        Chicken Burrito  [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-G...   $8.49
# 0    51   1                            Canned Soda                                  [Diet Dr. Pepper]   $1.09
# 0    52   1                       Steak Soft Tacos  [[Roasted Chili Corn Salsa (Medium), Tomatillo...   $8.99
# 0    52   1                    Chips and Guacamole                                               NULL   $3.99
# 0    53   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0    53   1                       Barbacoa Burrito  [Tomatillo Green Chili Salsa, [Rice, Black Bea...   $9.25
# 0    53   1                    Chips and Guacamole                                               NULL   $4.45
# 0    54   1                           Chicken Bowl  [Fresh Tomato Salsa, [Guacamole, Cheese, Sour ...  $11.25
# 0    54   1                    Chips and Guacamole                                               NULL   $4.45
# 0    55   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0    55   1                            Canned Soda                                        [Coca Cola]   $1.09
# 0    56   1                          Barbacoa Bowl  [Tomatillo Red Chili Salsa, [Rice, Pinto Beans...   $9.25
# 0    56   1    Chips and Tomatillo Red Chili Salsa                                               NULL   $2.95
# 0    56   1                    Chips and Guacamole                                               NULL   $4.45
# 0    57   1                       Barbacoa Burrito  [Roasted Chili Corn Salsa, [Rice, Pinto Beans,...  $11.75
# 0    57   1                    Chips and Guacamole                                               NULL   $4.45
# 0    58   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0    58   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0    59   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...  $10.98
# 0    60   2                     Chicken Salad Bowl  [Tomatillo Green Chili Salsa, [Sour Cream, Che...  $22.50
# 0    61   1                          Barbacoa Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.75
# 0    61   1                    Chips and Guacamole                                               NULL   $4.45
# 0    62   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...  $11.25
# 0    62   1                    Chips and Guacamole                                               NULL   $4.45
# 0    63   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Rice, Sour Crea...  $11.25
# 0    63   1                    Chips and Guacamole                                               NULL   $4.45
# 0    64   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0    64   1                            Veggie Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.25
# 0    65   1                       Barbacoa Burrito  [Tomatillo Red Chili Salsa, [Rice, Sour Cream,...  $11.75
# 0    65   1                          Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Fajita Veget...   $9.25
# 0    65   1                    Chips and Guacamole                                               NULL   $4.45
# 0    66   1                          Steak Burrito  [Tomatillo-Green Chili Salsa (Medium), [Rice, ...  $11.48
# 0    67   2                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...  $17.98
# 0    67   1                          Side of Chips                                               NULL   $1.69
# 0    68   2                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $17.50
# 0    68   1                    Chips and Guacamole                                               NULL   $4.45
# 0    69   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0    69   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0    70   2                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $17.50
# 0    70   1                    Chips and Guacamole                                               NULL   $4.45
# 0    71   1                    Chips and Guacamole                                               NULL   $4.45
# 0    71   1                            Veggie Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.25
# 0    71   1                          Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, G...  $11.75
# 0    72   1                        Chicken Burrito  [[Roasted Chili Corn Salsa (Medium), Tomatillo...  $10.98
# 0    73   1                           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...   $8.49
# 0    73   1                        Chicken Burrito  [[Roasted Chili Corn Salsa (Medium), Tomatillo...  $10.98
# 0    73   2                            Canned Soda                                        [Diet Coke]   $2.18
# 0    74   1                          Carnitas Bowl  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...  $11.48
# 0    74   1                            Veggie Bowl  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...   $8.49
# 0    74   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0    75   1                    Chips and Guacamole                                               NULL   $4.45
# 0    75   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.25
# 0    75   1                  Barbacoa Crispy Tacos  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.75
# 0    75   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Cheese, Sou...   $8.75
# 0    76   1                        Chicken Burrito  [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomat...   $8.49
# 0    76   2                            Canned Soda                                  [Diet Dr. Pepper]   $2.18
# 0    77   1                        Chicken Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.49
# 0    77   1                       Nantucket Nectar                                            [Apple]   $3.39
# 0    78   1                        Chicken Burrito    [Tomatillo-Green Chili Salsa (Medium), Lettuce]   $8.49
# 0    78   1                       Steak Soft Tacos       [Roasted Chili Corn Salsa (Medium), Lettuce]   $8.99
# 0    79   1                           Chicken Bowl  [Roasted Chili Corn Salsa (Medium), [Black Bea...  $10.98
# 0    80   1                          Steak Burrito  [Fresh Tomato Salsa (Mild), [Rice, Black Beans...  $11.48
# 0    81   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Rice, ...   $8.49
# 0    81   1                            Canned Soda                                        [Coca Cola]   $1.09
# 0    81   1                            Canned Soda                                       [Dr. Pepper]   $1.09
# 0    82   1                    Barbacoa Soft Tacos  [Tomatillo Red Chili Salsa, [Rice, Pinto Beans...   $9.25
# 0    82   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...   $8.75
# 0    82   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0    83   1                       Steak Soft Tacos         [Fresh Tomato Salsa, [Cheese, Sour Cream]]   $9.25
# 0    83   1                    Chips and Guacamole                                               NULL   $4.45
# 0    83   1                      Veggie Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0    84   1                             Steak Bowl  [Fresh Tomato Salsa (Mild), [Rice, Fajita Vegg...  $11.48
# 0    84   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Che...   $8.49
# 0    84   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Che...   $8.49
# 0    85   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Fajita Ve...   $8.99
# 0    85   1     Chips and Roasted Chili-Corn Salsa                                               NULL   $2.39
# 0    86   1                            Veggie Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.25
# 0    86   1                           Chicken Bowl   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0    86   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0    87   1                            Canned Soda                                        [Coca Cola]   $1.09
# 0    87   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0    88   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0    88   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0    89   1                           Chicken Bowl  [[Roasted Chili Corn Salsa (Medium), Tomatillo...  $10.98
# 0    89   1                            Canned Soda                                        [Diet Coke]   $1.09
# 0    89   1                    Chips and Guacamole                                               NULL   $3.99
# 0    90   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.25
# 0    90   1                        Chicken Burrito  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...   $8.75
# 0    91   1                        Chicken Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.49
# 0    91   1                       Nantucket Nectar                                     [Peach Orange]   $3.39
# 0    92   1                           Chicken Bowl      [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]   $8.75
# 0    92   1                             Steak Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $9.25
# 0    92   1                                  Chips                                               NULL   $2.15
# 0    93   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.25
# 0    93   1                            Veggie Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...  $11.25
# 0    93   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.25
# 0    93   1                    Chips and Guacamole                                               NULL   $4.45
# 0    94   2                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...  $22.50
# 0    95   1                    Chips and Guacamole                                               NULL   $4.45
# 0    95   1                             Steak Bowl  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...  $11.75
# 0    96   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0    96   2                   Chicken Crispy Tacos  [Tomatillo Red Chili Salsa, [Cheese, Sour Crea...  $17.50
# 0    96   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Rice, Black Bea...   $8.75
# 0    97   1                          Barbacoa Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $9.25
# 0    97   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $8.75
# 0    97   1                                  Chips                                               NULL   $2.15
# 0    98   1                       Barbacoa Burrito  [Tomatillo Red Chili Salsa, [Rice, Cheese, Let...   $9.25
# 0    98   2                                  Chips                                               NULL   $4.30
# 0    98   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...   $8.75
# 0    99   1                         Veggie Burrito  [Tomatillo Red Chili Salsa, [Black Beans, Chee...  $11.25
# 0    99   1                                  Chips                                               NULL   $2.15
# 0   100   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0   100   1                            Canned Soda                                     [Mountain Dew]   $1.09
# 0   101   1                          Steak Burrito  [Tomatillo-Green Chili Salsa (Medium), [Black ...   $8.99
# 0   101   1                    Chips and Guacamole                                               NULL   $3.99
# 0   102   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $8.75
# 0   102   1  Chips and Tomatillo Green Chili Salsa                                               NULL   $2.95
# 0   102   1     Chips and Roasted Chili Corn Salsa                                               NULL   $2.95
# 0   103   1                          Steak Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.75
# 0   103   2  Chips and Tomatillo Green Chili Salsa                                               NULL   $5.90
# 0   103   1                          Steak Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $9.25
# 0   103   1                    Carnitas Soft Tacos  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...   $9.25
# 0   103   1                          Steak Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.75
# 0   104   1                       Carnitas Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour ...   $9.25
# 0   104   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0   105   2                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $17.50
# 0   106   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...   $8.75
# 0   106   1                             Steak Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...   $9.25
# 0   107   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...  $10.98
# 0   108   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...   $8.99
# 0   108   1                            Canned Soda                                     [Mountain Dew]   $1.09
# 0   108   1                            Canned Soda                                       [Dr. Pepper]   $1.09
# 0   108   1                            Canned Soda                                     [Mountain Dew]   $1.09
# 0   108   1                       Barbacoa Burrito  [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomat...   $8.99
# 0   109   1                          Chicken Salad  [Roasted Chili Corn Salsa (Medium), [Black Bea...  $10.98
# 0   109   1                            Canned Soda                                  [Diet Dr. Pepper]   $1.09
# 0   110   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Rice, Cheese, Let...   $8.75
# 0   110   1                            Veggie Bowl  [Roasted Chili Corn Salsa, [Rice, Pinto Beans,...   $8.75
# 0   110   1                          Barbacoa Bowl  [Tomatillo Red Chili Salsa, [Rice, Cheese, Let...   $9.25
# 0   110   1                  Barbacoa Crispy Tacos  [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...   $9.25
# 0   111   1                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $8.75
# 0   111   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]   $8.75
# 0   112   1                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...   $8.99
# 0   112   1                             Steak Bowl  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...   $8.99
# 0   113   1                             Steak Bowl  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0   113   1                            Canned Soda                                     [Mountain Dew]   $1.09
# 0   114   1                             Steak Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...  $11.75
# 0   114   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   115   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Black Bea...   $8.99
# 0   115   1           Chips and Fresh Tomato Salsa                                               NULL   $2.39
# 0   116   1                       Steak Soft Tacos      [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]   $9.25
# 0   116   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0   117   1                    Barbacoa Soft Tacos  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...   $8.99
# 0   117   1                    Chips and Guacamole                                               NULL   $3.99
# 0   118   1                        Chicken Burrito  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...   $8.49
# 0   118   1  Chips and Tomatillo-Green Chili Salsa                                               NULL   $2.39
# 0   119   1                        Chicken Burrito  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...   $8.49
# 0   119   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Black Bea...   $8.49
# 0   120   1                        Chicken Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.49
# 0   120   1                          Side of Chips                                               NULL   $1.69
# 0   121   1                        Chicken Burrito  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...   $8.49
# 0   121   1                    Chips and Guacamole                                               NULL   $3.99
# 0   122   1                       Steak Soft Tacos  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...   $8.99
# 0   122   1                          Side of Chips                                               NULL   $1.69
# 0   122   1                            Canned Soda                                        [Coca Cola]   $1.09
# 0   123   2                       Steak Salad Bowl  [Tomatillo Red Chili Salsa, [Black Beans, Chee...  $23.78
# 0   124   2                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $17.50
# 0   124   1                                  Chips                                               NULL   $2.15
# 0   124   1                           Chicken Bowl   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0   125   1                             Steak Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $9.25
# 0   125   1                             Steak Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $9.25
# 0   125   1                            Veggie Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $8.75
# 0   125   1                    Chips and Guacamole                                               NULL   $4.45
# 0   126   1                        Chicken Burrito   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0   126   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.25
# 0   127   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Rice, Sour Crea...  $11.25
# 0   127   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0   128   1                       Steak Soft Tacos         [Fresh Tomato Salsa, [Cheese, Sour Cream]]   $9.25
# 0   128   1                    Chips and Guacamole                                               NULL   $4.45
# 0   128   1                      Veggie Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...  $11.25
# 0   129   1                          Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, G...  $11.75
# 0   129   1                          Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, G...  $11.75
# 0   129   1                      6 Pack Soft Drink                                           [Sprite]   $6.49
# 0   130   1                       Steak Soft Tacos         [Tomatillo-Red Chili Salsa (Hot), Lettuce]   $8.99
# 0   130   1    Chips and Tomatillo-Red Chili Salsa                                               NULL   $2.39
# 0   131   1                           Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Fajita Vegg...   $8.49
# 0   131   1           Chips and Fresh Tomato Salsa                                               NULL   $2.39
# 0   132   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.25
# 0   132   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0   132   1                                  Chips                                               NULL   $2.15
# 0   133   1                             Steak Bowl  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0   133   1                          Side of Chips                                               NULL   $1.69
# 0   134   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0   134   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.25
# 0   134   1                                  Chips                                               NULL   $2.15
# 0   135   1                    Chips and Guacamole                                               NULL   $4.45
# 0   135   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0   136   1                     Chicken Soft Tacos  [Tomatillo-Red Chili Salsa (Hot), Fajita Veggies]   $8.49
# 0   136   1                          Steak Burrito  [Tomatillo-Green Chili Salsa (Medium), [Cheese...   $8.99
# 0   137   2                     Chicken Salad Bowl            [Fresh Tomato Salsa, Fajita Vegetables]  $17.50
# 0   138   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...   $8.49
# 0   138   1                            Canned Soda                                        [Diet Coke]   $1.09
# 0   138   1                          Bottled Water                                               NULL   $1.09
# 0   139   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $8.75
# 0   139   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   139   1                                  Chips                                               NULL   $2.15
# 0   140   1                          Steak Burrito  [Fresh Tomato (Mild), [Lettuce, Guacamole, Ric...  $11.08
# 0   141   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...   $8.49
# 0   141   1                     Chicken Soft Tacos  [[Roasted Chili Corn Salsa (Medium), Tomatillo...   $8.49
# 0   142   1                          Steak Burrito          [Roasted Chili Corn Salsa (Medium), Rice]   $8.99
# 0   142   1           Chips and Fresh Tomato Salsa                                               NULL   $2.39
# 0   143   1                           Chicken Bowl        [Tomatillo Red Chili Salsa, [Rice, Cheese]]   $8.75
# 0   143   1                                  Chips                                               NULL   $2.15
# 0   143   1                          Bottled Water                                               NULL   $1.50
# 0   144   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.25
# 0   144   1                                  Chips                                               NULL   $2.15
# 0   145   1                     Chicken Soft Tacos  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...   $8.49
# 0   145   1                     Chicken Soft Tacos  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...   $8.49
# 0   146   1                       Barbacoa Burrito  [Roasted Chili Corn Salsa, [Rice, Black Beans,...  $11.75
# 0   146   1                          Steak Burrito  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $9.25
# 0   147   1                             Steak Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.75
# 0   147   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   148   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.25
# 0   148   1                        Chicken Burrito  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...   $8.75
# 0   148   1                    Chips and Guacamole                                               NULL   $4.45
# 0   148   1                      6 Pack Soft Drink                                        [Diet Coke]   $6.49
# 0   149   1                       Steak Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $9.25
# 0   149   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0   149   1                     Chicken Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...  $11.25
# 0   149   1                    Chips and Guacamole                                               NULL   $4.45
# 0   149   1                      Canned Soft Drink                                         [Lemonade]   $1.25
# 0   149   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0   150   1                           Chicken Bowl  [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...   $8.49
# 0   150   1    Chips and Tomatillo-Red Chili Salsa                                               NULL   $2.39
# 0   150   2                            Canned Soda                                        [Diet Coke]   $2.18
# 0   151   1                        Chicken Burrito  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...   $8.49
# 0   151   2                            Canned Soda                                        [Coca Cola]   $2.18
# 0   152   2                          Steak Burrito  [Fresh Tomato (Mild), [Lettuce, Guacamole, Ric...  $22.16
# 0   153   2                     Chicken Soft Tacos                   [Fresh Tomato Salsa, Sour Cream]  $17.50
# 0   154   1                        Chicken Burrito  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...   $8.75
# 0   154   1    Chips and Tomatillo Red Chili Salsa                                               NULL   $2.95
# 0   154   1                      6 Pack Soft Drink                                             [Coke]   $6.49
# 0   155   1                          Steak Burrito  [Fresh Tomato Salsa (Mild), [Pinto Beans, Chee...   $8.99
# 0   155   1                                   Izze                                       [Blackberry]   $3.39
# 0   155   1                                   Izze                                       [Grapefruit]   $3.39
# 0   156   1                          Steak Burrito  [Fresh Tomato Salsa (Mild), [Cheese, Sour Crea...   $8.99
# 0   156   1                        Chicken Burrito  [Fresh Tomato Salsa (Mild), [Pinto Beans, Chee...   $8.49
# 0   157   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.25
# 0   157   1                                  Chips                                               NULL   $2.15
# 0   158   1                   Chicken Crispy Tacos  [Tomatillo Green Chili Salsa, [Black Beans, Ch...  $11.25
# 0   158   1  Chips and Tomatillo Green Chili Salsa                                               NULL   $2.95
# 0   159   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Rice, Fajita Veget...  $11.25
# 0   159   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0   160   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Black Bea...   $8.99
# 0   160   1                            Canned Soda                                        [Diet Coke]   $1.09
# 0   161   1                           Chicken Bowl   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0   161   1                        Chicken Burrito   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0   162   1                       Carnitas Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour ...   $9.25
# 0   162   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0   163   1                       Barbacoa Burrito  [Roasted Chili Corn Salsa, [Rice, Black Beans,...  $11.75
# 0   163   1                          Bottled Water                                               NULL   $1.50
# 0   164   1                          Steak Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Bla...   $8.99
# 0   164   1                            Canned Soda                                     [Mountain Dew]   $1.09
# 0   165   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.25
# 0   165   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   165   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   166   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...  $11.25
# 0   166   1                          Steak Burrito  [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...  $11.75
# 0   166   1                                  Chips                                               NULL   $2.15
# 0   167   1                       Barbacoa Burrito  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...   $8.99
# 0   167   1                          Side of Chips                                               NULL   $1.69
# 0   168   1                             Steak Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.75
# 0   168   1                      6 Pack Soft Drink                                        [Diet Coke]   $6.49
# 0   169   1                        Chicken Burrito         [Fresh Tomato Salsa, [Cheese, Sour Cream]]   $8.75
# 0   169   1                       Steak Soft Tacos         [Fresh Tomato Salsa, [Cheese, Sour Cream]]   $9.25
# 0   170   1                        Chicken Burrito  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0   170   1                    Chips and Guacamole                                               NULL   $4.45
# 0   170   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   171   1                         Veggie Burrito           [Tomatillo Green Chili Salsa, Guacamole]  $11.25
# 0   171   1                    Chips and Guacamole                                               NULL   $4.45
# 0   172   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...   $8.49
# 0   172   1                       Barbacoa Burrito  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...   $8.99
# 0   173   1                        Chicken Burrito  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...   $8.49
# 0   173   1                          Carnitas Bowl  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...   $8.99
# 0   174   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Rice, Black Beans,...  $11.25
# 0   174   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0   175   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.75
# 0   175   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   176   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...  $11.75
# 0   176   1                    Carnitas Soft Tacos            [Fresh Tomato Salsa, [Cheese, Lettuce]]   $9.25
# 0   176   1                    Chips and Guacamole                                               NULL   $4.45
# 0   177   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.25
# 0   177   1                                  Chips                                               NULL   $2.15
# 0   178   3                           Chicken Bowl  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...  $32.94
# 0   179   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0   179   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Sour Cream, Che...  $11.25
# 0   180   1                             Steak Bowl  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...  $11.48
# 0   180   1                          Side of Chips                                               NULL   $1.69
# 0   180   1                            Canned Soda                                       [Dr. Pepper]   $1.09
# 0   181   2                           Chicken Bowl                        [Tomatillo Red Chili Salsa]  $17.50
# 0   182   1                    Chips and Guacamole                                               NULL   $4.45
# 0   182   1                      6 Pack Soft Drink                                        [Diet Coke]   $6.49
# 0   182   1                          Barbacoa Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $9.25
# 0   183   1                     Chicken Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $8.75
# 0   183   1                          Steak Burrito  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...   $9.25
# 0   184   1                       Carnitas Burrito  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...   $9.25
# 0   184   1                           Chicken Bowl        [Roasted Chili Corn Salsa, [Rice, Lettuce]]   $8.75
# 0   184   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $8.75
# 0   184   1                                  Chips                                               NULL   $2.15
# 0   184   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0   185   2                     Chicken Soft Tacos        [Fresh Tomato Salsa, [Sour Cream, Lettuce]]  $17.50
# 0   186   1                     Chicken Soft Tacos  [[Tomatillo-Red Chili Salsa (Hot), Roasted Chi...  $10.98
# 0   186   1                             Steak Bowl  [[Roasted Chili Corn Salsa (Medium), Tomatillo...  $11.48
# 0   186   1                  Barbacoa Crispy Tacos  [[Roasted Chili Corn Salsa (Medium), Tomatillo...  $11.48
# 0   186   1                                   Izze                                       [Grapefruit]   $3.39
# 0   187   1                          Steak Burrito  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...   $8.99
# ...
# 0  1785   1                        Chicken Burrito    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]   $8.75
# 0  1785   1                          Bottled Water                                               NULL   $1.50
# 0  1785   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0  1786   1                           Chicken Bowl                         [Fresh Tomato Salsa, Rice]   $8.75
# 0  1786   1                       Carnitas Burrito  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.75
# 0  1786   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...  $11.25
# 0  1786   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0  1786   1                          Barbacoa Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.75
# 0  1786   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.25
# 0  1786   1                       Carnitas Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Guaca...  $11.75
# 0  1786   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $8.75
# 0  1786   4                    Chips and Guacamole                                               NULL  $17.80
# 0  1786   4                      Canned Soft Drink                                             [Coke]   $5.00
# 0  1786   4                      Canned Soft Drink                                           [Sprite]   $5.00
# 0  1787   1                        Chicken Burrito  [Tomatillo Green Chili Salsa, [Rice, Black Bea...   $8.75
# 0  1787   1  Chips and Tomatillo Green Chili Salsa                                               NULL   $2.95
# 0  1787   1                      Canned Soft Drink                                         [Lemonade]   $1.25
# 0  1788   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour ...  $11.25
# 0  1788   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1788   1                                  Chips                                               NULL   $2.15
# 0  1789   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...  $11.25
# 0  1789   2                      Canned Soft Drink                                             [Coke]   $2.50
# 0  1789   1                          Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $9.25
# 0  1790   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1790   1                     Chicken Soft Tacos  [Fresh Tomato Salsa, [Cheese, Guacamole, Lettu...  $11.25
# 0  1790   1           Chips and Fresh Tomato Salsa                                               NULL   $2.95
# 0  1791   1                          Carnitas Bowl  [Fresh Tomato Salsa, [Rice, Sour Cream, Guacam...  $11.75
# 0  1791   1                                  Chips                                               NULL   $2.15
# 0  1792   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...  $11.25
# 0  1792   1                          Bottled Water                                               NULL   $1.50
# 0  1793   1                          Steak Burrito                                       [Brown Rice]   $8.99
# 0  1793   1                                  Chips                                               NULL   $1.99
# 0  1793   1                          Barbacoa Bowl                                        [Guacamole]  $11.49
# 0  1794   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Rice, Fajita Veget...   $8.75
# 0  1794   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1794   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0  1795   1                     Chicken Soft Tacos   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0  1795   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1795   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1796   1                          Bottled Water                                               NULL   $1.50
# 0  1796   1                             Steak Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...  $11.75
# 0  1797   1                         Veggie Burrito  [Fresh Tomato Salsa, [Rice, Pinto Beans, Cheese]]   $8.75
# 0  1797   1                     Chicken Salad Bowl                      [Fresh Tomato Salsa, Lettuce]   $8.75
# 0  1798   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Guacamole, Lettuce...  $11.25
# 0  1798   1                      6 Pack Soft Drink                                        [Diet Coke]   $6.49
# 0  1798   1                     Steak Crispy Tacos  [Tomatillo Green Chili Salsa, [Cheese, Sour Cr...  $11.75
# 0  1799   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $8.75
# 0  1799   1                                  Chips                                               NULL   $2.15
# 0  1799   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1800   1                      6 Pack Soft Drink                                        [Diet Coke]   $6.49
# 0  1800   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...   $8.75
# 0  1800   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1801   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $8.75
# 0  1801   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1802   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...   $8.75
# 0  1802   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.25
# 0  1803   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1803   1                      6 Pack Soft Drink                                         [Lemonade]   $6.49
# 0  1803   1                          Steak Burrito  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $9.25
# 0  1804   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0  1804   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0  1804   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1805   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...  $11.25
# 0  1805   1                      Veggie Salad Bowl  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...   $8.75
# 0  1806   1                          Bottled Water                                               NULL   $1.50
# 0  1806   1                        Chicken Burrito    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]   $8.75
# 0  1806   1                          Bottled Water                                               NULL   $1.50
# 0  1806   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0  1807   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]   $9.25
# 0  1807   1                       Steak Salad Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $9.39
# 0  1808   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1808   1                       Steak Soft Tacos  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...   $9.25
# 0  1809   1                     Chicken Soft Tacos  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...   $8.75
# 0  1809   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1809   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1810   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Black Beans, Sour ...  $11.25
# 0  1810   1                     Steak Crispy Tacos  [Roasted Chili Corn Salsa, [Fajita Vegetables,...  $11.75
# 0  1811   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $8.75
# 0  1811   1                        Chicken Burrito  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...  $11.25
# 0  1811   1                    Carnitas Soft Tacos  [Tomatillo Red Chili Salsa, [Fajita Vegetables...   $9.25
# 0  1812   1                        Chicken Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0  1812   1                        Chicken Burrito  [Tomatillo Red Chili Salsa, [Rice, Cheese, Gua...  $11.25
# 0  1812   2                      Canned Soft Drink                                             [Coke]   $2.50
# 0  1813   2                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...  $17.50
# 0  1814   1                          Carnitas Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...   $9.25
# 0  1814   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1815   1                           Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...  $11.25
# 0  1815   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1816   1                        Chicken Burrito  [Roasted Chili Corn Salsa, [Pinto Beans, Chees...   $8.75
# 0  1816   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1817   1                          Bottled Water                                               NULL   $1.50
# 0  1817   1                        Chicken Burrito    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]   $8.75
# 0  1817   1                          Bottled Water                                               NULL   $1.50
# 0  1817   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0  1818   1                       Steak Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...   $9.39
# 0  1818   1                      Veggie Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...   $8.75
# 0  1819   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...   $8.75
# 0  1819   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1820   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...  $11.25
# 0  1820   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0  1821   1                       Carnitas Burrito  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...   $9.25
# 0  1821   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1822   1                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...  $11.25
# 0  1822   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0  1822   2                          Bottled Water                                               NULL   $3.00
# 0  1823   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Rice, Black Bea...   $8.75
# 0  1823   1                                  Chips                                               NULL   $2.15
# 0  1823   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0  1824   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.25
# 0  1824   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...  $11.25
# 0  1824   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1825   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...  $11.25
# 0  1825   1                           Chicken Bowl  [Roasted Chili Corn Salsa, [Rice, Black Beans,...  $11.25
# 0  1825   1                           Chicken Bowl  [Tomatillo Red Chili Salsa, [Rice, Black Beans...   $8.75
# 0  1825   1                       Barbacoa Burrito  [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...  $11.75
# 0  1825   1                          Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...  $11.75
# 0  1825   1                          Barbacoa Bowl  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...  $11.75
# 0  1826   1                           Chicken Bowl  [Tomatillo Green Chili Salsa, [Rice, Black Bea...   $8.75
# 0  1826   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1826   1                      Canned Soft Drink                                           [Nestea]   $1.25
# 0  1826   1                          Bottled Water                                               NULL   $1.50
# 0  1827   1                           Chicken Bowl      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]   $8.75
# 0  1827   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1827   1                      Canned Soft Drink                                        [Diet Coke]   $1.25
# 0  1827   1                       Barbacoa Burrito                      [Tomatillo Green Chili Salsa]   $9.25
# 0  1827   1                       Barbacoa Burrito                      [Tomatillo Green Chili Salsa]   $9.25
# 0  1828   1                           Chicken Bowl  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...   $8.75
# 0  1828   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1828   1                      Canned Soft Drink                                             [Coke]   $1.25
# 0  1829   1                          Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...  $11.75
# 0  1829   1                         Veggie Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...  $11.25
# 0  1829   1                      Canned Soft Drink                                           [Sprite]   $1.25
# 0  1830   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...  $11.75
# 0  1830   1                         Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...  $11.25
# 0  1831   1                          Carnitas Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...   $9.25
# 0  1831   1                                  Chips                                               NULL   $2.15
# 0  1831   1                          Bottled Water                                               NULL   $1.50
# 0  1832   1                     Chicken Soft Tacos   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]   $8.75
# 0  1832   1                    Chips and Guacamole                                               NULL   $4.45
# 0  1833   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...  $11.75
# 0  1833   1                          Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...  $11.75
# 0  1834   1                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...  $11.25
# 0  1834   1                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...   $8.75
# 0  1834   1                     Chicken Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...   $8.75

# %% [markdown]
# ---
#
# ## Intermediate Level

# %% [markdown]
# ### Part 3: Calculate the average price of an order.
#
# Hint: Examine the data to see if the `quantity` column is relevant to this calculation.
#
# Hint: Think carefully about the simplest way to do this!

# %%
# Take the $ signs out of the item price so it can be treated as a numeric
chipotle['item_price'] = chipotle['item_price'].replace('[\$,]', '', regex=True).astype(float)

# %%
# Groupby order_id so I can get a sum of the price of each item in the order
orders = chipotle.groupby(['order_id'])['item_price'].sum().reset_index() 
orders.head()
# Out:
#    order_id  item_price
# 0         1       11.56
# 1         2       16.98
# 2         3       12.67
# 3         4       21.00
# 4         5       13.70

# %%
# Average price is the sum of all of the orders divided by the count of the orders
avg_price = orders['item_price'].sum() / orders['order_id'].count()
print("The average order price is ${}".format(round(avg_price,2)))
# Out:
# The average order price is $18.81

# %% [markdown]
# ### Part 4: Create a list (or set) named `unique_sodas` containing all of unique sodas and soft drinks that Chipotle sells.
#
# Note: Just look for `'Canned Soda'` and `'Canned Soft Drink'`, and ignore other drinks like `'Izze'`.

# %%
# Grab just the item name and description columns then select only the rows that are sodas
sodas = chipotle[['item_name','choice_description']]
sodas = sodas[(sodas['item_name'] == 'Canned Soda') | (sodas['item_name'] == 'Canned Soft Drink')]

# Select only the unique soda choices
unique_sodas = sodas['choice_description'].unique()
print(unique_sodas)
# Out:
# ['[Sprite]' '[Dr. Pepper]' '[Mountain Dew]' '[Diet Dr. Pepper]'
#  '[Coca Cola]' '[Diet Coke]' '[Coke]' '[Lemonade]' '[Nestea]']

# %% [markdown]
# ---
#
# ## Advanced Level

# %% [markdown]
# ### Part 5: Calculate the average number of toppings per burrito.
#
# Note: Let's ignore the `quantity` column to simplify this task.
#
# Hint: Think carefully about the easiest way to count the number of toppings!

# %%
# Select all items that end in burrito
burritos = chipotle[chipotle['item_name'].str[-7:] == 'Burrito']

# The number of toppings is equal to the number of commas plus 1
burritos['count'] = burritos['choice_description'].str.count(",") + 1

print("The average number of topings per burrito is {}".format(burritos['count'].mean()))
burritos.head(10)
# Out:
# The average number of topings per burrito is 5.395051194539249
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#     order_id  quantity         item_name  \
# 7          4         1     Steak Burrito
# 9          5         1     Steak Burrito
# 16         8         1   Chicken Burrito
# 17         9         1   Chicken Burrito
# 21        11         1  Barbacoa Burrito
# 23        12         1   Chicken Burrito
# 27        14         1  Carnitas Burrito
# 29        15         1   Chicken Burrito
# 31        16         1     Steak Burrito
# 43        20         1     Steak Burrito
#
#                                    choice_description  item_price  count
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75      8
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25      7
# 16  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49      4
# 17  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...        8.49      6
# 21  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...        8.99      7
# 23  [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98      8
# 27  [[Tomatillo-Green Chili Salsa (Medium), Roaste...        8.99      6
# 29  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49      5
# 31  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99      5
# 43  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75      7

# %% [markdown]
# ### Part 6: Create a dictionary. Let the keys represent chip orders and the values represent the total number of orders.
#
# Expected output: `{'Chips and Roasted Chili-Corn Salsa': 18, ... }`
#
# Note: Please take the `quantity` column into account!
#
# Optional: Learn how to use `.defaultdict()` to simplify your code.

# %%
# Select all the orders and limit it to the item name and quantity
all_orders = chipotle[['item_name','quantity']]

# Select the orders that have the word chip in them
chip_orders = all_orders[all_orders['item_name'].str.contains('chip', case=False, regex=True)]
chip_orders.head()
# Out:
#                                 item_name  quantity
# 0            Chips and Fresh Tomato Salsa         1
# 3   Chips and Tomatillo-Green Chili Salsa         1
# 6                           Side of Chips         1
# 10                    Chips and Guacamole         1
# 14                    Chips and Guacamole         1

# %%
# Group by item_name and sum the quantity
grouped = chip_orders.groupby('item_name')['quantity'].sum().reset_index()
# Create an empty dict
chip_dict = {}

# For loop that enters each row as a dict entry
for i in range(len(grouped)):
    chip_dict[grouped.loc[i,:]['item_name']] = grouped.loc[i,:]['quantity']
print(chip_dict)
# Out:
# {'Chips': 230, 'Chips and Fresh Tomato Salsa': 130, 'Chips and Guacamole': 506, 'Chips and Mild Fresh Tomato Salsa': 1, 'Chips and Roasted Chili Corn Salsa': 23, 'Chips and Roasted Chili-Corn Salsa': 18, 'Chips and Tomatillo Green Chili Salsa': 45, 'Chips and Tomatillo Red Chili Salsa': 50, 'Chips and Tomatillo-Green Chili Salsa': 33, 'Chips and Tomatillo-Red Chili Salsa': 25, 'Side of Chips': 110}

# %% [markdown]
# ---
#
# ## Bonus: Craft a problem statement about this data that interests you, and then answer it!

# %%
# Problem Statement: Determine the probability of each topping being put on a burrito

# Select only the burritos
burritos = chipotle[chipotle['item_name'].str[-7:] == 'Burrito']

# reset the index so I can iterate the df and get the number of burritos by summing the quantity
burritos = burritos.reset_index()
number_of_burritos = burritos['quantity'].sum()

# function that takes a string of toppings and the number of orders of the burrito and returns a df with each topping
def get_toppings_df(toppings, num):
    quantity = num
    # Calculae the number of toppings in the string for the for loop
    toppings_num =  toppings.count(",") + 1
    toppings_string = toppings
    # Create empty df for returning from the function
    return_df = pd.DataFrame(columns=['toppings', 'quantity'])
    # The for loop uses the commas via find function to separate the toppings and add them to the df
    for i in range(1,toppings_num):
        comma = toppings_string.find(',')
        topping = toppings_string[0:comma]
        toppings_string = toppings_string[comma+2:]
        return_df = return_df.append({'toppings':topping, 'quantity':quantity}, ignore_index=True)
    # Return the df
    return return_df


# Create empty df for populating
all_the_toppings = pd.DataFrame(columns=['toppings', 'quantity'])

# for loop removes all the brackets so it looks pretty and calls the function to get the toppings split
for index, row in burritos.iterrows():
    # Remove the brakcets
    semi_processed = row['choice_description'].replace(']', '')
    fully_processed = semi_processed.replace('[', '')
    # Get the number of orders for that burrito
    quantity = burritos.loc[index,:]['quantity']
    # Call the function and get df with each topping in the string as a df
    new_rows = get_toppings_df(fully_processed, quantity)
    # Append the df to the total df
    all_the_toppings = all_the_toppings.append(new_rows)

# Calculate the sum of each topping
topping_count = all_the_toppings.groupby('toppings')['quantity'].sum().reset_index()

# Sort the toppings by most popular to least
topping_count = topping_count.sort_values(by='quantity', ascending=False)

# Get the probability of each topping
topping_probability = topping_count
topping_probability['probability'] = topping_probability['quantity'] / number_of_burritos

# For loop to iterate the df and print the probability with a nice format
for index, row in topping_probability.iterrows():
    print(" There is a {}% probability that {} will be in a burrito".format(round(row['probability']*1000)/10, row['toppings']))
# Out:
#  There is a 86.1% probability that Rice will be in a burrito
#  There is a 70.2% probability that Cheese will be in a burrito
#  There is a 47.3% probability that Sour Cream will be in a burrito
#  There is a 45.8% probability that Black Beans will be in a burrito
#  There is a 32.7% probability that Fresh Tomato Salsa will be in a burrito
#  There is a 23.3% probability that Pinto Beans will be in a burrito
#  There is a 19.2% probability that Guacamole will be in a burrito
#  There is a 19.0% probability that Fajita Vegetables will be in a burrito
#  There is a 13.4% probability that Fresh Tomato Salsa (Mild) will be in a burrito
#  There is a 12.3% probability that Roasted Chili Corn Salsa will be in a burrito
#  There is a 12.2% probability that Tomatillo Red Chili Salsa will be in a burrito
#  There is a 11.5% probability that Fajita Veggies will be in a burrito
#  There is a 10.8% probability that Roasted Chili Corn Salsa (Medium) will be in a burrito
#  There is a 9.4% probability that Tomatillo-Red Chili Salsa (Hot) will be in a burrito
#  There is a 7.7% probability that Tomatillo Green Chili Salsa will be in a burrito
#  There is a 7.5% probability that Lettuce will be in a burrito
#  There is a 5.7% probability that Tomatillo-Green Chili Salsa (Medium) will be in a burrito
#  There is a 1.5% probability that Fresh Tomato (Mild) will be in a burrito
#  There is a 0.4% probability that Salsa will be in a burrito
#  There is a 0.2% probability that Tomatillo Red Chili (Hot) will be in a burrito
#  There is a 0.2% probability that Adobo-Marinated and Grilled Chicken will be in a burrito
#  There is a 0.2% probability that Roasted Chili Corn (Medium) will be in a burrito
#  There is a 0.2% probability that Adobo-Marinated and Grilled Steak will be in a burrito
#  There is a 0.2% probability that Cilantro-Lime Rice will be in a burrito
#  There is a 0.2% probability that Braised Barbacoa will be in a burrito
#  There is a 0.2% probability that White Rice will be in a burrito
#  There is a 0.1% probability that Tomatillo Green Chili (Medium) will be in a burrito
#  There is a 0.1% probability that Vegetarian Black Beans will be in a burrito
