# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Classification and KNN with NHL data
#
# _Authors: Joseph Nelson (DC)_
#
# ---
#
# Below you will practice KNN classification on a dataset of NHL statistics.
#
# You will be predicting the `Rank` of a team from predictor variables of your choice.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# web location:
local_csv = '../../data/NHL_Data_GA.csv'

# %% [markdown]
# ### 1. Load the NHL data

# %%
# A:

nhl = pd.read_csv(local_csv)

# %% [markdown]
# ### 2. Perform any required data cleaning. Do some EDA.

# %%
# A:

nhl.head()
# Out:
#            Team  PTS  Rank         TOI   GF  GA  GF60  GA60   GF%    SF  ...  \
# 0  Washington10  121     1  2001:52:00  115  73  3.45  2.19  61.2  1112  ...
# 1   Vancouver11  117     1  2056:14:00   94  72  2.74  2.10  56.6  1143  ...
# 2    San Jose10  113     1  1929:54:00   90  68  2.80  2.11  57.0  1065  ...
# 3     Chicago10  112     1  2020:23:00  104  83  3.09  2.46  55.6  1186  ...
# 4   Vancouver12  111     1  2052:02:00   86  74  2.51  2.16  53.8  1078  ...
#
#     FF%    CF    CA  CF60  CA60   CF%    Sh%    Sv%   PDO   PIM
# 0  51.3  2138  1935  64.1  58.0  52.5  10.34  93.03  1034  1269
# 1  53.1  2144  1870  62.6  54.6  53.4   8.22  93.16  1014   985
# 2  50.9  1985  1876  61.7  58.3  51.4   8.45  93.46  1019  1195
# 3  58.1  2093  1572  62.2  46.7  57.1   8.77  90.44   992   966
# 4  51.0  2085  1880  61.0  55.0  52.6   7.98  93.36  1013  1049
#
# [5 rows x 28 columns]

# %%
nhl.shape
# Out:
# (90, 28)

# %%
nhl.dtypes
# Out:
# Team     object
# PTS       int64
# Rank      int64
# TOI      object
# GF        int64
# GA        int64
# GF60    float64
# GA60    float64
# GF%     float64
# SF        int64
# SA        int64
# SF60    float64
# SA60    float64
# SF%     float64
# FF        int64
# FA        int64
# FF60    float64
# FA60    float64
# FF%     float64
# CF        int64
# CA        int64
# CF60    float64
# CA60    float64
# CF%     float64
# Sh%     float64
# Sv%     float64
# PDO       int64
# PIM       int64
# dtype: object

# %%
nhl.describe()
# Out:
#               PTS       Rank          GF          GA       GF60       GA60  \
# count   90.000000  90.000000   90.000000   90.000000  90.000000  90.000000
# mean    91.977778   2.022222   83.288889   83.288889   2.442222   2.444000
# std     12.524114   0.820767   10.376339    9.694484   0.325331   0.313522
# min     62.000000   1.000000   57.000000   64.000000   1.700000   1.730000
# 25%     82.250000   1.000000   76.000000   75.500000   2.232500   2.202500
# 50%     92.500000   2.000000   84.000000   84.000000   2.400000   2.495000
# 75%    102.000000   3.000000   90.000000   89.000000   2.600000   2.670000
# max    121.000000   3.000000  115.000000  107.000000   3.450000   3.240000
#
#              GF%           SF           SA       SF60  ...        FF%  \
# count  90.000000    90.000000    90.000000  90.000000  ...  90.000000
# mean   49.981111  1068.333333  1068.333333  31.252222  ...  49.966667
# std     4.644554    95.929047    75.514118   2.237637  ...   2.797913
# ...

# %%
nhl.isnull().sum()
# Out:
# Team    0
# PTS     0
# Rank    0
# TOI     0
# GF      0
# GA      0
# GF60    0
# GA60    0
# GF%     0
# SF      0
# SA      0
# SF60    0
# SA60    0
# SF%     0
# FF      0
# FA      0
# FF60    0
# FA60    0
# FF%     0
# CF      0
# CA      0
# CF60    0
# CA60    0
# CF%     0
# Sh%     0
# Sv%     0
# PDO     0
# PIM     0
# dtype: int64

# %%
corr = nhl.corr()

fig, ax = plt.subplots(figsize=(9,7))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

ax = sns.heatmap(corr, mask=mask, ax=ax)

ax.set_xticklabels(ax.xaxis.get_ticklabels(), fontsize=14)
ax.set_yticklabels(ax.yaxis.get_ticklabels(), fontsize=14)

plt.show()

# %% [markdown]
# ### 3. Set up the `Rank` variable as your target. How many classes are there?

# %%
# A:

nhl.Rank.nunique() #gets the number of uniques
# There are 3 classes: 1, 2 and 3
# Out:
# 3

# %%
nhl.Rank.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
y = nhl.Rank

# %% [markdown]
# ### 4. What is the baseline accuracy?

# %%
# A: the baseline would be Rank 3, as it has the largest representation.

y.value_counts()/y.count()
# Out:
# 3    0.344444
# 2    0.333333
# 1    0.322222
# Name: Rank, dtype: float64

# %% [markdown]
# ### 5. Choose 4 features to be your predictor variables and set up your design matrix.

# %%
# A:

feature_cols = ['CF%', 'FF%', 'SF60', 'GA60']
X = nhl[feature_cols]

# %%
X.head()
# Out:
#     CF%   FF%  SF60  GA60
# 0  52.5  51.3  33.3  2.19
# 1  53.4  53.1  33.4  2.10
# 2  51.4  50.9  33.1  2.11
# 3  57.1  58.1  35.2  2.46
# 4  52.6  51.0  31.5  2.16

# %%
print(X.shape)
print(y.shape)
# Out:
# (90, 4)
# (90,)

# %% [markdown]
# ### 6. Fit a `KNeighborsClassifier` with 1 neighbor using the target and predictors.

# %%
# A:

from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# ### 7. Evaluate the accuracy of your model.
# - Is it better than baseline?
# - Is it legitimate?

# %%
# A:

y_pred_class = knn.predict(X)
print(metrics.accuracy_score(y, y_pred_class))
# Out:
# 1.0

# %%
# An accuracy of 100%, like the above, indicates overfitting, making the model non-reliabale.

# %% [markdown]
# ### 8. Create a 50-50 train-test-split of your target and predictors. Refit the KNN and assess the accuracy.

# %%
# A:
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=99, test_size=0.5)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
y_pred_class = knn.predict(X_test)
print((metrics.accuracy_score(y_test, y_pred_class)))
# Out:
# 0.5111111111111111

# %% [markdown]
# ### 9. Evaluate the test accuracy of a KNN where K == number of rows in the training data.

# %%
# A:

knn = KNeighborsClassifier(n_neighbors=X_train.shape[0])
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=45, p=2,
#                      weights='uniform')

# %%
y_pred_class = knn.predict(X_test)
print((metrics.accuracy_score(y_test, y_pred_class)))
# Out:
# 0.3111111111111111

# %% [markdown]
# ### 10. Fit the KNN at values of K from 1 to the number of rows in the training data.
# - Store the test accuracy in a list.
# - Plot the test accuracy vs. the number of neighbors.

# %%
# A:

test_accuracy = []
for k in range(1, X_train.shape[0]+1):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    test_accuracy.append(knn.score(X_test, y_test))

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(list(range(1, X_train.shape[0]+1)), test_accuracy, lw=3.)
plt.show()

# %% [markdown]
# ### 11. Fit KNN across different values of K and plot the mean cross-validated accuracy with 5 folds.

# %%
# A:

from sklearn.model_selection import cross_val_score

max_neighbors = np.floor(X.shape[0] - X.shape[0]/5.)

print(max_neighbors)
# Out:
# 72.0

# %%
test_accuracy = []
for k in range(1, int(max_neighbors)):
    knn = KNeighborsClassifier(n_neighbors=k)
    test_accuracy.append(np.mean(cross_val_score(knn, X, y, cv=5)))

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(list(range(1, int(max_neighbors))), test_accuracy, lw=3.)
plt.show()

# %% [markdown]
# ### 12. Standardize the predictor matrix and cross-validate across the different K.
# - Plot the standardized mean cross-validated accuracy against the unstandardized. Which is better?
# - Why?

# %%
# A:
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)

# %%
std_test_accuracy = []
for k in range(1, int(max_neighbors)):
    knn = KNeighborsClassifier(n_neighbors=k)
    std_test_accuracy.append(np.mean(cross_val_score(knn, X_scaler, y, cv=5)))

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(list(range(1, int(max_neighbors))), test_accuracy, lw=3.)
ax.plot(list(range(1, int(max_neighbors))), std_test_accuracy, lw=3., color='darkred')
plt.show()
